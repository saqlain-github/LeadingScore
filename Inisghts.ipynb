# %% [markdown]
# ## Experiment Steps
#
# 1. Check for duplicated
# 2. Handling Missing values
#     - More than 40% missing values
#         - Lead Quality                  -> fill na's with Not sure
#         - 'Asymmetrique Activity Index' -> fill na with Nan- new data as Nan
#         -  Asymmetrique Profile Index ->  fill na with Nan- new data as Nan
#         - 'Asymmetrique Activity Score'
#         - 'Asymmetrique Profile Score'  -> Score are in range 7-15, we will assign 0 as for Null values
#
#     - Less than 40% missing values :
#
#         - 'Lead Source'                   -> there is data impurity, so replace null with most occuring and reduce number of categories
#         - 'Last Activity'                 -> Replace with Nan most occuring category
#         - 'Country'                       -> there is data impurity, so replace null with most occuring and reduce number of categories(Other International Cities)
#         - 'Specialization'                -> Replace Select and NUll with Unknown
#         - 'How did you hear about X Education' -> Replace Select and NUll with Unknown
#         - 'What is your current occupation'    -> Replace with Nan most occuring category
#         - 'What matters most to you in choosing a course' -> Replace with Nan most occuring category
#         - 'Tags'                           -> Mark Null values as Unknown
#         - 'Lead Profile'                   -> Replace Select and NUll with Unknown
#         - 'City'                           -> Replace Select and NUll with Unknown
#
#         - "TotalVisits"
#         - "Page Views Per Visit"   -> filling values with median
#
# 3. Data Impurity
#     - Columns with Null values:
#         - Country -> mark other countries except India as other international countries
#         - City    -> Handle Mumbai city marked as other international Countries
#         - Tags
#     - Columns without Null Values
#         - Last Notable Activity -> converted less count categories to new category as other
#
# 4. Correlation of Independent and dependent Features:
#     - Categorical Features
#         - Features with high skewness and no corration with Converted Features are dropped
#             - 'Country'
#             - 'What matters most to you in choosing a course',
#             - 'Search'
#             - 'Do Not Call'
#             - 'Newspaper Article'
#             - 'X Education Forums',
#             - 'Newspaper',
#             - 'Digital Advertisement',
#             - 'Through Recommendations'
#             - 'Magazine',
#             - 'Receive More Updates About Our Courses',
#             - 'Update me on Supply Chain Content'
#             - 'Get updates on DM Content',
#             - 'I agree to pay the amount through cheque'
#
#         - Features which show corration with Converted Features
#             - 'Tags'
#             - 'Lead Source'
#             - 'Specialization'
#             - 'How did you hear about X Education',
#             - 'What is your current occupation'
#             - 'Lead Profile'
#             - 'City',
#             - 'Last Activity'
#             - 'Lead Origin'
#             - 'Last Notable Activity',
#             - 'Lead Quality'
#             - 'Asymmetrique Activity Index',
#             - 'Asymmetrique Profile Index'
#             - 'Do Not Email',
#             - 'A free copy of Mastering The Interview'
#
#     - Correlation between continuous and Converted Features
#         - "TotalVisits"
#         - "Total Time Spent on Website"
#         - "Page Views Per Visit"            -> dont show any correlation
#         - 'Asymmetrique Activity Score'     -> dont show any correlation
#         - 'Asymmetrique Profile Score'      -> dont show any correlation
#
# 4. Data Visualization
#         - 'Tags' - Higest number of Converts are from Unknown categories, we marked these category as 'Unknown in case of select. If we make this field mandatory we can come up with strategy to target specific tags
#
#         - 'Lead Source' - Google and Direct help in getting intereseted people so we can concentrate on these categories more
#
#         - 'Specialization' - Higest number of Converts are from Unknown categories, we marked these category as 'Unknown in case of select. If we make this field mandatory we can come up with strategy to target specific Specilization.
#
#         - 'How did you hear about X Education' - Higest number of Converts are from Unknown categories, we marked these category as 'Unknown in case of select. If we make this field mandatory we can come up with strategy to target specific How did you hear about X Education.
#
#         - 'What is your current occupation' - Unemployed people tend to Convert to lead probably because they want to learn a new skill
#
#         - 'Lead Profile' -
#         - 'City' -  Specifically Mumbai tends to have more Leads
#         - 'Last Activity' - SMS and Email tends to attract more number of Leads
#         - 'Lead Origin' - Landing Page Submission and API can improve number of leads
#         - 'Last Notable Activity' - Modified, Email and SMS can give high number of leads
#         - 'Lead Quality' - People who are not Sure can be converted to more candidates with some amount of push from staff or attractive offers
#         - 'Asymmetrique Activity Index' -
#         - 'Asymmetrique Profile Index'
#         - 'Do Not Email' - People tend to not like Emails to notify about the product
#         - 'A free copy of Mastering The Interview'

# %% [markdown]
# ### Each Column Data Types
#
# - Numerical
#   1. Continuous : Scaling and Normalization
#         - "TotalVisits"
#         - "Total Time Spent on Website"
#         - "Page Views Per Visit"
#
#
#   2. Discrete : Scaling
#         - 'Asymmetrique Activity Score'
#         - 'Asymmetrique Profile Score'
#
# - Categorical
#     1. Ordinal : Label Encoding
#         - 'Lead Quality' -
#         - 'Asymmetrique Activity Index'
#         -  Asymmetrique Profile Index
#
#     2. Nominal : OneHotEncoding
#         - "Tags"
#         - "Lead Source"
#         - "Specialization"
#         - "How did you hear about X Education"
#         - 'What is your current occupation'
#         - "Lead Profile"
#         - "City"
#         - "Last Activity"
#         - "Lead Origin"
#         - Last Notable Activity
#
#         <!-- - "Country"
#         - 'What matters most to you in choosing a course'
#         - 'Search' -->
#
#     3. Binary :
#         - Do Not Email                    - [8506, 734]
#         - A free copy of Mastering The Interview -> looks good
#
#         <!-- - Do Not Call                     - [9238, 2] -> skewed
#         - Newspaper Article               - [9238, 2] -> skewed
#         - X Education Forums              - [9239, 1] -> skewed
#         - Newspaper	                      - [9239, 1] -> skewed
#         - Search                          - [9226, 14]
#         - 'Digital Advertisement'         - [9236, 4]
#         - 'Through Recommendations'       - [9233, 7] -->
#         -
#
#     <!-- 4. Uniary - to be dropped
#         - Magazine - Contains only No category
#         - 'Receive More Updates About Our Courses'
#         - 'Update me on Supply Chain Content
#         - 'Get updates on DM Content',
#         - 'I agree to pay the amount through cheque',
#         - 'A free copy of Mastering The Interview' -->
#
#
#
#
# 4. Target :
#         - Converted
#
# -  List of Dropped Columns
#
#     - "Prospect ID"
#     - "Lead Number"
#     - 'Country'
#     - 'What matters most to you in choosing a course',
#     - 'Search'
#     - 'Do Not Call'
#     - 'Newspaper Article'
#     - 'X Education Forums',
#     - 'Newspaper',
#     - 'Digital Advertisement',
#     - 'Through Recommendations'
#     - 'Magazine',
#     - 'Receive More Updates About Our Courses',
#     - 'Update me on Supply Chain Content'
#     - 'Get updates on DM Content',
#     - 'I agree to pay the amount through cheque'
